# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
data = pd.read_csv('Live.csv')
data.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
data.drop(columns=['status_id','status_type','status_published','Column1','Column2','Column3','Column4'],axis=1,inplace=True)

# %%
data.sample(10)
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 224             191             2           2        188          2         1
# 5767             42             0           0         40          0         2
# 3813              1             0           0          1          0         0
# 434             254             5           0        252          2         0
# 6271            985            71          42        962          5        16
# 2439             23             1           0         23          0         0
# 3682              0             0           0          0          0         0
# 6776            147           383          10        142          2         0
# 2766             17             2           0         17          0         0
# 4194              2             0           0          2          0         0
#
#       num_hahas  num_sads  num_angrys
# 224           0         0           0
# ...

# %%
data.corr()
# Out:
#                num_reactions  num_comments  num_shares  num_likes  num_loves  \
# num_reactions       1.000000      0.150843    0.250723   0.994923   0.305003
# num_comments        0.150843      1.000000    0.640637   0.101687   0.521223
# num_shares          0.250723      0.640637    1.000000   0.172492   0.820000
# num_likes           0.994923      0.101687    0.172492   1.000000   0.209308
# num_loves           0.305003      0.521223    0.820000   0.209308   1.000000
# num_wows            0.267752      0.162394    0.407628   0.207800   0.508798
# num_hahas           0.176028      0.325048    0.399826   0.120784   0.507830
# num_sads            0.075138      0.236453    0.199970   0.052169   0.207600
# num_angrys          0.124326      0.225184    0.312513   0.087431   0.371001
#
#                num_wows  num_hahas  num_sads  num_angrys
# num_reactions  0.267752   0.176028  0.075138    0.124326
# num_comments   0.162394   0.325048  0.236453    0.225184
# ...

# %%
data.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x = 'num_likes', y='num_reactions',data=data)

# %%
plt.scatter(x='num_loves',y='num_shares',data=data)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
scaled_x = sc.fit_transform(data)

# %%
scaled_x
# Out:
# array([[ 0.64610394,  0.32335035,  1.6868788 , ...,  0.07671305,
#          0.47357035, -0.15574803],
#        [-0.17319166, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.00673846,  0.01308938,  0.12901714, ...,  0.07671305,
#         -0.152587  , -0.15574803],
#        ...,
#        [-0.49312768, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [ 0.26131603, -0.23871662, -0.13695924, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-0.46070173, -0.25220622, -0.3041444 , ..., -0.17600986,
#         -0.152587  , -0.15574803]])

# %%
noise_percent = []
for i in np.linspace(0.001,3,50):
    model = DBSCAN(eps=i)
    model.fit(scaled_x)
    
    noise = 100 * np.sum(model.labels_ == -1 ) / len(model.labels_)
    noise_percent.append(noise)
noise_percent
# Out:
# [73.13475177304964,
#  29.43262411347518,
#  24.099290780141843,
#  21.347517730496453,
#  19.829787234042552,
#  17.092198581560282,
#  15.106382978723405,
#  13.106382978723405,
#  11.787234042553191,
#  10.4822695035461,
#  9.75886524822695,
#  8.879432624113475,
#  7.872340425531915,
#  7.035460992907802,
#  6.652482269503546,
#  6.340425531914893,
#  5.858156028368795,
#  5.546099290780142,
#  5.304964539007092,
#  4.950354609929078,
#  4.836879432624113,
#  4.539007092198582,
#  4.25531914893617,
#  4.127659574468085,
#  4.0,
#  3.702127659574468,
#  3.475177304964539,
#  3.3617021276595747,
#  3.219858156028369,
#  3.078014184397163,
#  2.978723404255319,
#  2.7943262411347516,
#  2.624113475177305,
#  2.4680851063829787,
#  2.326241134751773,
#  2.297872340425532,
#  2.127659574468085,
#  2.0709219858156027,
#  1.9858156028368794,
#  1.9432624113475176,
#  1.9148936170212767,
#  1.8865248226950355,
#  1.7730496453900708,
#  1.7588652482269505,
#  1.702127659574468,
# ...

# %%
sns.lineplot(x=np.linspace(0.001,3,50),y=noise_percent)
# Out:
# <AxesSubplot:>

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN(eps=1.5)

# %%
model.fit(scaled_x)
# Out:
# DBSCAN(eps=1.5)

# %%
model.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='num_loves',y='num_shares',data=data,hue=model.labels_,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='num_loves', ylabel='num_shares'>

# %%
data['cluster'] = model.labels_

# %%
data
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               529           512         262        432         92         3
# 1               150             0           0        150          0         0
# 2               227           236          57        204         21         1
# 3               111             0           0        111          0         0
# 4               213             0           0        204          9         0
# ...             ...           ...         ...        ...        ...       ...
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
# ...

# %%
data[data['cluster'] == -1]
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 6               503           614          72        418         70        10
# 99             1493          1979         753       1333        139         9
# 107             190             0          31        171          0         0
# 128             688             0           0        632         34         0
# 166            4410           633         257       4315         73        17
# ...             ...           ...         ...        ...        ...       ...
# 6915            205          2635         146        171         29         1
# 6932            159          3146         123        139         16         0
# 6955            266          5000         153        234         27         2
# 6964            211          4487         135        186         22         1
# 6974            300          5404         219        245         44         1
#
# ...
